# %%
#Try bring in the csv file here

# %%
import pandas as pd

df = pd.read_csv("City Temperature without row numbers.csv")
df
# Out:
#            City  temp10  temp11  empty_temp  mel_temp
# 0  Kuala Lumpur      32      32         NaN         5
# 1       Banting      29      30         NaN         4
# 2         Klang      31      31         NaN         1
# 3     Shah Alam      30      29         NaN         5
# 4     Damansara      28      30         NaN         2

# %%
df = pd.read_csv("City Temperature.csv")
df
# Out:
#    Unnamed: 0          City  temp10  temp11  empty_temp  mel_temp
# 0           0  Kuala Lumpur      32      32         NaN         5
# 1           1       Banting      29      30         NaN         4
# 2           2         Klang      31      31         NaN         1
# 3           3     Shah Alam      30      29         NaN         5
# 4           4     Damansara      28      30         NaN         2

# %%
df.drop("Unnamed: 0" ,axis=1) #drop column, axis =1
# Out:
#            City  temp10  temp11  empty_temp  mel_temp
# 0  Kuala Lumpur      32      32         NaN         5
# 1       Banting      29      30         NaN         4
# 2         Klang      31      31         NaN         1
# 3     Shah Alam      30      29         NaN         5
# 4     Damansara      28      30         NaN         2

# %%
df2 = pd.read_csv("City Temperature without row numbers.csv")
df2
# Out:
#            City  temp10  temp11  empty_temp  mel_temp
# 0  Kuala Lumpur      32      32         NaN         5
# 1       Banting      29      30         NaN         4
# 2         Klang      31      31         NaN         1
# 3     Shah Alam      30      29         NaN         5
# 4     Damansara      28      30         NaN         2

# %%
df3 = pd.read_csv("/Users/fakrulzahir/Desktop/AIML-B8/DailyPractise/Global_Superstore.csv")
df3
# Out:
#        Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891  31-07-2012  31-07-2012        Same Day
# 1       26341    IN-2013-77878  05-02-2013  07-02-2013    Second Class
# 2       25330    IN-2013-71249  17-10-2013  18-10-2013     First Class
# 3       13524  ES-2013-1579342  28-01-2013  30-01-2013     First Class
# 4       47221     SG-2013-4320  05-11-2013  06-11-2013        Same Day
# ...       ...              ...         ...         ...             ...
# 51285   29002    IN-2014-62366  19-06-2014  19-06-2014        Same Day
# 51286   35398   US-2014-102288  20-06-2014  24-06-2014  Standard Class
# 51287   40470   US-2013-155768  02-12-2013  02-12-2013        Same Day
# 51288    9596   MX-2012-140767  18-02-2012  22-02-2012  Standard Class
# 51289    6147   MX-2012-134460  22-05-2012  26-05-2012    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# ...
